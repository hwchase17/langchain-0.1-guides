# %% [markdown]
# # Streaming
#
# This notebook covers functionality related to streaming.
#
# For more information, see:
#
# - [Streaming with LCEL](https://python.langchain.com/docs/expression_language/interface#stream)
#
# - [Streaming for RAG](https://python.langchain.com/docs/use_cases/question_answering/streaming)
#
# - [Streaming for Agents](https://python.langchain.com/docs/modules/agents/how_to/streaming)

# %% [markdown]
# ## Basic Streaming

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain = prompt | model | output_parser

# %%
for s in chain.stream({"topic": "bears"}):
    print(s)
# Out:
# Why
#  don
# 't
#  bears
#  wear
#  shoes
# ?
#
#
# Because
#  they
#  have
#  bear
#  feet
# !

# %% [markdown]
# ## Streaming with RunnableParallel

# %%
from langchain_core.runnables import RunnableParallel

prompt = ChatPromptTemplate.from_template("Tell me a joke about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain1 = prompt | model | output_parser

prompt = ChatPromptTemplate.from_template("Write me a poem about {topic}")
model = ChatOpenAI()
output_parser = StrOutputParser()
chain2 = prompt | model | output_parser

parallel_chain = RunnableParallel({
    "joke": chain1,
    "poem": chain2
})

for s in parallel_chain.stream({"topic": "bears"}):
    print(s)
# Out:
# {'poem': ''}
# {'poem': 'In'}
# {'poem': ' a'}
# {'joke': ''}
# {'poem': ' land'}
# {'joke': 'Why'}
# {'joke': ' don'}
# {'joke': "'t"}
# {'joke': ' bears'}
# {'poem': ' where'}
# {'joke': ' wear'}
# {'poem': ' wilderness'}
# {'joke': ' shoes'}
# {'joke': '?\n\n'}
# {'joke': 'Because'}
# {'joke': ' they'}
# {'joke': ' have'}
# {'joke': ' bear'}
# {'poem': ' reign'}
# {'joke': ' feet'}
# {'joke': '!'}
# {'poem': 's'}
# {'poem': ' supreme'}
# {'poem': ',\n'}
# {'joke': ''}
# {'poem': 'Where'}
# {'poem': ' mighty'}
# {'poem': ' rivers'}
# {'poem': ' flow'}
# {'poem': ' and'}
# {'poem': ' mountains'}
# {'poem': ' gle'}
# {'poem': 'am'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' creature'}
# {'poem': ' ro'}
# {'poem': 'ams'}
# {'poem': ','}
# {'poem': ' majestic'}
# {'poem': ' and'}
# {'poem': ' grand'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' guardian'}
# {'poem': ' of'}
# {'poem': ' nature'}
# {'poem': "'s"}
# {'poem': ' sacred'}
# {'poem': ' land'}
# {'poem': '.\n\n'}
# {'poem': 'Beh'}
# {'poem': 'old'}
# {'poem': ' the'}
# {'poem': ' bear'}
# {'poem': ','}
# {'poem': ' with'}
# {'poem': ' strength'}
# {'poem': ' unt'}
# {'poem': 'amed'}
# {'poem': ',\n'}
# {'poem': 'With'}
# {'poem': ' fur'}
# {'poem': ' so'}
# {'poem': ' thick'}
# {'poem': ','}
# {'poem': ' with'}
# {'poem': ' power'}
# {'poem': ' unt'}
# {'poem': 'amed'}
# {'poem': ',\n'}
# {'poem': 'From'}
# {'poem': ' Arctic'}
# {'poem': ' realms'}
# {'poem': ' to'}
# {'poem': ' forests'}
# {'poem': ' deep'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' fearless'}
# {'poem': ' soul'}
# {'poem': ' that'}
# {'poem': ' does'}
# {'poem': ' not'}
# {'poem': ' sleep'}
# {'poem': '.\n\n'}
# {'poem': 'In'}
# {'poem': ' the'}
# {'poem': ' heart'}
# {'poem': ' of'}
# {'poem': ' winter'}
# {'poem': "'s"}
# {'poem': ' icy'}
# {'poem': ' embrace'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' bear'}
# {'poem': ' retreat'}
# {'poem': 's'}
# {'poem': ' to'}
# {'poem': ' find'}
# {'poem': ' a'}
# {'poem': ' tranquil'}
# {'poem': ' space'}
# {'poem': ',\n'}
# {'poem': 'C'}
# {'poem': 'oc'}
# {'poem': 'oon'}
# {'poem': 'ed'}
# {'poem': ' in'}
# {'poem': ' sl'}
# {'poem': 'umber'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' peaceful'}
# {'poem': ' rest'}
# {'poem': ',\n'}
# {'poem': 'Await'}
# {'poem': 'ing'}
# {'poem': ' spring'}
# {'poem': "'s"}
# {'poem': ' warm'}
# {'poem': ' touch'}
# {'poem': ','}
# {'poem': ' it'}
# {'poem': "'s"}
# {'poem': ' manifest'}
# {'poem': '.\n\n'}
# {'poem': 'With'}
# {'poem': ' the'}
# {'poem': ' awakening'}
# {'poem': ' of'}
# {'poem': ' nature'}
# {'poem': "'s"}
# {'poem': ' might'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' bear'}
# {'poem': ' emerges'}
# {'poem': ','}
# {'poem': ' ready'}
# {'poem': ' to'}
# {'poem': ' ignite'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' sym'}
# {'poem': 'phony'}
# {'poem': ' of'}
# {'poem': ' life'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' dance'}
# {'poem': ' so'}
# {'poem': ' rare'}
# {'poem': ',\n'}
# {'poem': 'It'}
# {'poem': ' t'}
# {'poem': 'reads'}
# {'poem': ' the'}
# {'poem': ' earth'}
# {'poem': ' with'}
# {'poem': ' noble'}
# {'poem': ' flair'}
# {'poem': '.\n\n'}
# {'poem': 'Through'}
# {'poem': ' rugged'}
# {'poem': ' p'}
# {'poem': 'aws'}
# {'poem': ' and'}
# {'poem': ' piercing'}
# {'poem': ' eyes'}
# {'poem': ',\n'}
# {'poem': 'The'}
# {'poem': ' bear'}
# {'poem': "'s"}
# {'poem': ' wisdom'}
# {'poem': ','}
# {'poem': ' age'}
# {'poem': 'less'}
# {'poem': ' and'}
# {'poem': ' wise'}
# {'poem': ',\n'}
# {'poem': 'It'}
# {'poem': ' tells'}
# {'poem': ' tales'}
# {'poem': ' of'}
# {'poem': ' ancient'}
# {'poem': ' lands'}
# {'poem': ' unknown'}
# {'poem': ',\n'}
# {'poem': 'Of'}
# {'poem': ' secrets'}
# {'poem': ' whispered'}
# {'poem': ','}
# {'poem': ' but'}
# {'poem': ' never'}
# {'poem': ' shown'}
# {'poem': '.\n\n'}
# {'poem': 'In'}
# {'poem': ' pursuit'}
# {'poem': ' of'}
# {'poem': ' sust'}
# {'poem': 'enance'}
# {'poem': ','}
# {'poem': ' it'}
# {'poem': ' journeys'}
# {'poem': ' far'}
# {'poem': ',\n'}
# {'poem': 'Through'}
# {'poem': ' dense'}
# {'poem': ' forest'}
# {'poem': ' and'}
# {'poem': ' shimmer'}
# {'poem': 'ing'}
# {'poem': ' star'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' master'}
# {'poem': ' fish'}
# {'poem': 'er'}
# {'poem': ' in'}
# {'poem': ' the'}
# {'poem': ' flowing'}
# {'poem': ' stream'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' berry'}
# {'poem': ' con'}
# {'poem': 'no'}
# {'poem': 'isseur'}
# {'poem': ','}
# {'poem': ' the'}
# {'poem': ' bear'}
# {'poem': "'s"}
# {'poem': ' fond'}
# {'poem': ' dream'}
# {'poem': '.\n\n'}
# {'poem': 'Yet'}
# {'poem': ','}
# {'poem': ' beyond'}
# {'poem': ' its'}
# {'poem': ' might'}
# {'poem': ' and'}
# {'poem': ' b'}
# {'poem': 'rawn'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' tender'}
# {'poem': ' soul'}
# {'poem': ' resides'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' spirit'}
# {'poem': ' drawn'}
# {'poem': ',\n'}
# {'poem': 'To'}
# {'poem': ' protect'}
# {'poem': ' its'}
# {'poem': ' kin'}
# {'poem': ','}
# {'poem': ' to'}
# {'poem': ' nurture'}
# {'poem': ' and'}
# {'poem': ' defend'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' love'}
# {'poem': ' that'}
# {'poem': ' knows'}
# {'poem': ' no'}
# {'poem': ' limit'}
# {'poem': ' or'}
# {'poem': ' end'}
# {'poem': '.\n\n'}
# {'poem': 'Oh'}
# {'poem': ','}
# {'poem': ' bear'}
# {'poem': ','}
# {'poem': ' embodiment'}
# {'poem': ' of'}
# {'poem': ' wilderness'}
# {'poem': ' divine'}
# {'poem': ',\n'}
# {'poem': 'Your'}
# {'poem': ' presence'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' symbol'}
# {'poem': ','}
# {'poem': ' so'}
# {'poem': ' sublime'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' reminder'}
# {'poem': ' of'}
# {'poem': ' nature'}
# {'poem': "'s"}
# {'poem': ' delicate'}
# {'poem': ' balance'}
# {'poem': ',\n'}
# {'poem': 'Of'}
# {'poem': ' harmony'}
# {'poem': ' and'}
# {'poem': ' strength'}
# {'poem': ','}
# {'poem': ' a'}
# {'poem': ' w'}
# {'poem': 'ondrous'}
# {'poem': ' trance'}
# {'poem': '.\n\n'}
# {'poem': 'So'}
# {'poem': ' let'}
# {'poem': ' us'}
# {'poem': ' honor'}
# {'poem': ' the'}
# {'poem': ' mighty'}
# {'poem': ' bear'}
# {'poem': "'s"}
# {'poem': ' embrace'}
# {'poem': ',\n'}
# {'poem': 'Res'}
# {'poem': 'pect'}
# {'poem': ' its'}
# {'poem': ' realm'}
# {'poem': ','}
# {'poem': ' its'}
# {'poem': ' sacred'}
# {'poem': ' space'}
# {'poem': ',\n'}
# {'poem': 'For'}
# {'poem': ' in'}
# {'poem': ' its'}
# {'poem': ' existence'}
# {'poem': ','}
# {'poem': ' we'}
# {'poem': ' find'}
# {'poem': ' a'}
# {'poem': ' connection'}
# {'poem': ',\n'}
# {'poem': 'A'}
# {'poem': ' reminder'}
# {'poem': ' of'}
# {'poem': ' our'}
# {'poem': ' own'}
# {'poem': ' humble'}
# {'poem': ' reflection'}
# {'poem': '.'}
# {'poem': ''}

# %%
result = {}
for s in parallel_chain.stream({"topic": "bears"}):
    for k,v in s.items():
        if k not in result:
            result[k] = ""
        result[k] += v
    print(result)
# Out:
# {'poem': ''}
# {'poem': '', 'joke': ''}
# {'poem': 'In', 'joke': ''}
# {'poem': 'In forests', 'joke': ''}
# {'poem': 'In forests deep', 'joke': ''}
# {'poem': 'In forests deep', 'joke': 'Why'}
# {'poem': 'In forests deep', 'joke': 'Why don'}
# {'poem': 'In forests deep', 'joke': "Why don't"}
# {'poem': 'In forests deep,', 'joke': "Why don't"}
# {'poem': 'In forests deep, where', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\n', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\nA', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\nA creature', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\nA creature ro', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams', 'joke': "Why don't"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams', 'joke': "Why don't bears"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams', 'joke': "Why don't bears wear"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams', 'joke': "Why don't bears wear shoes"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with', 'joke': "Why don't bears wear shoes"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with', 'joke': "Why don't bears wear shoes?\n\n"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with', 'joke': "Why don't bears wear shoes?\n\nBecause"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle', 'joke': "Why don't bears wear shoes?\n\nBecause"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance', 'joke': "Why don't bears wear shoes?\n\nBecause"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance', 'joke': "Why don't bears wear shoes?\n\nBecause they"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\n', 'joke': "Why don't bears wear shoes?\n\nBecause they"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\n', 'joke': "Why don't bears wear shoes?\n\nBecause they have"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith', 'joke': "Why don't bears wear shoes?\n\nBecause they have"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold,', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\n', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBeh', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': 'In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear', 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nB", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBene", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchant", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir p", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTr", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTravers", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmer", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuard", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thr", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives,", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace,\n", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace,\nFrom", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace,\nFrom snowy", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace,\nFrom snowy peaks", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# {'poem': "In forests deep, where shadows dance,\nA creature roams with gentle stance,\nWith fur of gold, a mighty frame,\nBehold the beauty of the bear's name.\n\nBeneath the moon's enchanting glow,\nThrough wilderness, they softly flow,\nTheir paws so big, but light as air,\nTraversing lands with utmost care.\n\nThey stand so tall, both strong and wise,\nWith piercing gaze, they mesmerize,\nGuardians of the wild, fierce and free,\nA symbol of strength, for all to see.\n\nTheir habitat, a sacred space,\nWhere nature thrives, in perfect grace,\nFrom snowy peaks to", 'joke': "Why don't bears wear shoes?\n\nBecause they have bear feet!"}
# ...
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\n", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears,", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears, throughout", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears, throughout our", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears, throughout our days", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears, throughout our days.", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}
# {'poem': "In the wilds where nature roams,\nA mighty presence proudly looms.\nWith fur that glistens, dark and fair,\nA creature known as the majestic bear.\n\nThrough rugged landscapes, they wander strong,\nTheir steps resounding, a rhythmic song.\nSilent hunters, keen and wise,\nThey tread softly, beneath the skies.\n\nBeneath the moon's enchanting light,\nThey dance with stars throughout the night.\nGraceful movements, both swift and grand,\nA ballet performed on untouched land.\n\nTheir paws, like pillows, tread with grace,\nLeaving imprints on this sacred space.\nIn forests deep, they find their rest,\nTheir dens a shelter, a cozy nest.\n\nWith strength unmatched and power untamed,\nBears navigate a world unclaimed.\nFrom polar realms of ice and snow,\nTo ancient forests, where rivers flow.\n\nIn their eyes, a wisdom deep,\nA soul that guards secrets they keep.\nProtectors of the lands they roam,\nFrom mountain peaks to valleys home.\n\nYet, amidst their might and fierce display,\nA tender side they also portray.\nFor cubs they cherish, with gentle care,\nGuiding them through life's uncertain lair.\n\nOh, bears, majestic, wild, and free,\nSymbols of strength and mystery.\nMay we respect and coexist,\nWith these guardians, we cannot resist.\n\nFor in their presence, we find a clue,\nTo live in harmony, old and new.\nLet us learn from their primal ways,\nAnd honor bears, throughout our days.", 'joke': "Why don't bears wear shoes? \n\nBecause they have bear feet!"}

# %% [markdown]
# ## Stream Log

# %%
from langchain_community.retrievers.tavily_search_api import TavilySearchAPIRetriever
from langchain_core.runnables import RunnablePassthrough

retriever= TavilySearchAPIRetriever()

prompt = ChatPromptTemplate.from_template("""Answer the question based only on the context provided:

Context: {context}

Question: {question}""")

chain = prompt | model | output_parser

retrieval_chain = RunnablePassthrough.assign(
    context=(lambda x: x["question"]) | retriever.with_config(run_name="Docs")
) | chain

# %%
for s in retrieval_chain.stream({"question": "what is langsmith"}):
    print(s, end="")
# Out:
# LangSmith is a platform that offers features for debugging, testing, evaluating, and monitoring language learning model (LLM) applications. It helps developers trace and evaluate their LLM applications and intelligent agents, allowing them to move from prototype to production. LangSmith provides visibility into model inputs and outputs, allows for dataset creation and testing, and offers a unified platform for various aspects of LLM development.

# %%
async for s in retrieval_chain.astream_log({"question": "what is langsmith"}):
    print(s, end="")
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': 'dc8e247b-9508-402a-a209-0c8ee2c9dbbe',
#             'logs': {},
#             'streamed_output': []}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableAssign<context>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '350e365c-cd45-4752-9cce-84ec522e663f',
#             'metadata': {},
#             'name': 'RunnableAssign<context>',
#             'start_time': '2024-01-07T20:16:46.188+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<context>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '9ecc7441-fdcc-4ce3-8b25-8c4a4453628e',
#             'metadata': {},
#             'name': 'RunnableParallel<context>',
#             'start_time': '2024-01-07T20:16:46.190+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'ba1fce02-7a9e-48ff-93a5-8ccbda42638b',
#             'metadata': {},
#             'name': 'RunnableSequence',
#             'start_time': '2024-01-07T20:16:46.191+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:context'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/<lambda>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'c314e934-9fa4-45ee-af8d-4884e45c2d2d',
#             'metadata': {},
#             'name': '<lambda>',
#             'start_time': '2024-01-07T20:16:46.193+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})RunLogPatch({'op': 'add',
#   'path': '/logs/<lambda>/final_output',
#   'value': {'output': 'what is langsmith'}},
#  {'op': 'add',
#   'path': '/logs/<lambda>/end_time',
#   'value': '2024-01-07T20:16:46.194+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '6c99c725-8732-41ef-8677-fbb81e4426a4',
#             'metadata': {},
#             'name': 'Docs',
#             'start_time': '2024-01-07T20:16:46.194+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'retriever'}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs/final_output',
#   'value': {'documents': [Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.93324, 'images': None}),
#                           Document(page_content='LangSmith. LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production.. Check out the interactive walkthrough to get started.. For more information, please refer to the LangSmith documentation.. For tutorials and other end-to-end examples demonstrating ways to integrate LangSmith in your workflow, check out the ...', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92377, 'images': None}),
#                           Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.91785, 'images': None}),
#                           Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.91084, 'images': None}),
#                           Document(page_content='We often use this for a couple of reasons:\nTo assess subjective qualities that automatic evaluators struggle with, like creativity or humor\nTo sample and validate a subset of runs that were auto-evaluated, ensuring the automatic metrics are still reliable and capturing the right information\nAll the annotations made using the queue are assigned as "feedback" to the source runs, so you can easily filter and analyze them later.\n This feature is available at every step of a nested chain, enabling you to add examples for an end-to-end chain, an intermediary chain (such as a LLM Chain), or simply the LLM or Chat Model.\n The LangSmith client makes it easy to pull down a dataset and then run a chain over them, logging the results to a new project associated with the dataset. LangChain simplifies the initial setup, but there is still work needed to bring the performance of prompts, chains and agents up the level where they are reliable enough to be used in production.\n You can also quickly edit examples and add them to datasets to expand the surface area of your evaluation sets or to fine-tune a model for improved quality or reduced costs.\n', metadata={'title': 'LangSmith Overview and User Guide | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/overview', 'score': 0.90624, 'images': None}),
#                           Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.89758, 'images': None}),
#                           Document(page_content='A deep dive into the latest product from the creators of LangChain 🦜\n--\n3\nCobus Greyling\nLangSmith\nI was fortunate to get early access to the LangSmith platform and in this article you will find practical code examples and demonstration…\n--\nLists\nNatural Language Processing\nPredictive Modeling w/ Python\nAI Regulation\nPractical Guides to Machine Learning\nYule Wang, PhD\nA Complete Guide to LLMs-based Autonomous Agents (Part I):\n—\u200a—\u200aChain of Thought, Plan and Solve/Execute, Self-Ask, ReAct, Reflexion, Self-Consistency, Tree of Thoughts and Graph of Thoughts\n--\n1\nRyan Nguyen\nin\nBetter Programming\nLlamaIndex: How To Evaluate Your RAG (Retrieval Augmented Generation) Applications\nClassic 10k reports with Australian real estate market reports to demonstrate the end-to-end evaluation process\n--\n2\nKelvin Lu\nTracing How LangChain Works Behind the Scenes\nIntroduction of LLM Tracing technique with both LangChain built-in tracing funciton and LangChain Visualizer.\n --\nCameron R. Wolfe, Ph.D.\nin\nTowards Data Science\nChain of Thought Prompting for LLMs\nA practical and simple approach for “reasoning” with LLMs\n--\nHelp\nStatus\nAbout\nCareers\nBlog\nPrivacy\nTerms\nText to speech\nTeams A Step-by-Step Guide to Deploying ChromaDB in the Cloud\n--\nBenoit Ruiz\nin\nBetter Programming\nAdvice From a Software Engineer With 8 Years of Experience\nPractical tips for those who want to advance in their careers\n--\n233\nVinita\nin\nBetter Programming\n4 Strategies to Give Effective Feedback to a Difficult Person\nRespect is like air. But if you take it away, it’s all that people can think about.\n--\n21\nRicardo Ledan\nin\nBetter Programming\nBuilding Context-Aware Question-Answering Systems With LLMs\nA step-by-step guide to using embeddings, vector search, and prompt engineering for building context-aware question-answering systems\n--\n1\nRecommended from Medium\nLogan Kilpatrick\nWhat is LangSmith and why should I care as a developer?\n Ricardo Ledan\nFollow\nBetter Programming\n--\nShare\nWhat is LangSmith?\n', metadata={'title': 'The Art of LangSmithing - Better Programming', 'source': 'https://betterprogramming.pub/the-art-of-langsmithing-42dcd191a220', 'score': 0.84902, 'images': None}),
#                           Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.84897, 'images': None}),
#                           Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.80609, 'images': None}),
#                           Document(page_content='Python Examples\u200b\nTypeScript / JavaScript Testing Examples\u200b\nIncorporate LangSmith into your TS/JS testing and evaluation workflow:\nUsing Feedback\u200b\nHarness user feedback, "ai-assisted" feedback, and other signals to improve, monitor, and personalize your applications. Feedback can be user-generated or "automated" using functions or even calls to an LLM:\nExporting data for fine-tuning\u200b\nFine-tune an LLM on collected run data using these recipes:\nExploratory Data Analysis\u200b\nTurn your trace data into actionable insights: LangSmith Cookbook\nThe LangSmith Cookbook offers hands-on code examples to inspire and assist in your projects.\n While our standard documentation covers the basics, this repository delves into common patterns and some real-world use-cases, empowering you to optimize your LLM applications further.\n While we\'ve incorporated summaries and overviews from the READMEs here, the full code resides\nin our GitHub repository.\n', metadata={'title': 'LangSmith Cookbook | ️ ️ LangSmith - docs.smith.langchain.com', 'source': 'https://docs.smith.langchain.com/cookbook', 'score': 0.80606, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/Docs/end_time',
#   'value': '2024-01-07T20:16:47.554+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/final_output',
#   'value': {'output': [Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.93324, 'images': None}),
#                        Document(page_content='LangSmith. LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production.. Check out the interactive walkthrough to get started.. For more information, please refer to the LangSmith documentation.. For tutorials and other end-to-end examples demonstrating ways to integrate LangSmith in your workflow, check out the ...', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92377, 'images': None}),
#                        Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.91785, 'images': None}),
#                        Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.91084, 'images': None}),
#                        Document(page_content='We often use this for a couple of reasons:\nTo assess subjective qualities that automatic evaluators struggle with, like creativity or humor\nTo sample and validate a subset of runs that were auto-evaluated, ensuring the automatic metrics are still reliable and capturing the right information\nAll the annotations made using the queue are assigned as "feedback" to the source runs, so you can easily filter and analyze them later.\n This feature is available at every step of a nested chain, enabling you to add examples for an end-to-end chain, an intermediary chain (such as a LLM Chain), or simply the LLM or Chat Model.\n The LangSmith client makes it easy to pull down a dataset and then run a chain over them, logging the results to a new project associated with the dataset. LangChain simplifies the initial setup, but there is still work needed to bring the performance of prompts, chains and agents up the level where they are reliable enough to be used in production.\n You can also quickly edit examples and add them to datasets to expand the surface area of your evaluation sets or to fine-tune a model for improved quality or reduced costs.\n', metadata={'title': 'LangSmith Overview and User Guide | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/overview', 'score': 0.90624, 'images': None}),
#                        Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.89758, 'images': None}),
#                        Document(page_content='A deep dive into the latest product from the creators of LangChain 🦜\n--\n3\nCobus Greyling\nLangSmith\nI was fortunate to get early access to the LangSmith platform and in this article you will find practical code examples and demonstration…\n--\nLists\nNatural Language Processing\nPredictive Modeling w/ Python\nAI Regulation\nPractical Guides to Machine Learning\nYule Wang, PhD\nA Complete Guide to LLMs-based Autonomous Agents (Part I):\n—\u200a—\u200aChain of Thought, Plan and Solve/Execute, Self-Ask, ReAct, Reflexion, Self-Consistency, Tree of Thoughts and Graph of Thoughts\n--\n1\nRyan Nguyen\nin\nBetter Programming\nLlamaIndex: How To Evaluate Your RAG (Retrieval Augmented Generation) Applications\nClassic 10k reports with Australian real estate market reports to demonstrate the end-to-end evaluation process\n--\n2\nKelvin Lu\nTracing How LangChain Works Behind the Scenes\nIntroduction of LLM Tracing technique with both LangChain built-in tracing funciton and LangChain Visualizer.\n --\nCameron R. Wolfe, Ph.D.\nin\nTowards Data Science\nChain of Thought Prompting for LLMs\nA practical and simple approach for “reasoning” with LLMs\n--\nHelp\nStatus\nAbout\nCareers\nBlog\nPrivacy\nTerms\nText to speech\nTeams A Step-by-Step Guide to Deploying ChromaDB in the Cloud\n--\nBenoit Ruiz\nin\nBetter Programming\nAdvice From a Software Engineer With 8 Years of Experience\nPractical tips for those who want to advance in their careers\n--\n233\nVinita\nin\nBetter Programming\n4 Strategies to Give Effective Feedback to a Difficult Person\nRespect is like air. But if you take it away, it’s all that people can think about.\n--\n21\nRicardo Ledan\nin\nBetter Programming\nBuilding Context-Aware Question-Answering Systems With LLMs\nA step-by-step guide to using embeddings, vector search, and prompt engineering for building context-aware question-answering systems\n--\n1\nRecommended from Medium\nLogan Kilpatrick\nWhat is LangSmith and why should I care as a developer?\n Ricardo Ledan\nFollow\nBetter Programming\n--\nShare\nWhat is LangSmith?\n', metadata={'title': 'The Art of LangSmithing - Better Programming', 'source': 'https://betterprogramming.pub/the-art-of-langsmithing-42dcd191a220', 'score': 0.84902, 'images': None}),
#                        Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.84897, 'images': None}),
#                        Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.80609, 'images': None}),
#                        Document(page_content='Python Examples\u200b\nTypeScript / JavaScript Testing Examples\u200b\nIncorporate LangSmith into your TS/JS testing and evaluation workflow:\nUsing Feedback\u200b\nHarness user feedback, "ai-assisted" feedback, and other signals to improve, monitor, and personalize your applications. Feedback can be user-generated or "automated" using functions or even calls to an LLM:\nExporting data for fine-tuning\u200b\nFine-tune an LLM on collected run data using these recipes:\nExploratory Data Analysis\u200b\nTurn your trace data into actionable insights: LangSmith Cookbook\nThe LangSmith Cookbook offers hands-on code examples to inspire and assist in your projects.\n While our standard documentation covers the basics, this repository delves into common patterns and some real-world use-cases, empowering you to optimize your LLM applications further.\n While we\'ve incorporated summaries and overviews from the READMEs here, the full code resides\nin our GitHub repository.\n', metadata={'title': 'LangSmith Cookbook | ️ ️ LangSmith - docs.smith.langchain.com', 'source': 'https://docs.smith.langchain.com/cookbook', 'score': 0.80606, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/RunnableSequence/end_time',
#   'value': '2024-01-07T20:16:47.558+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<context>/final_output',
#   'value': {'context': [Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.93324, 'images': None}),
#                         Document(page_content='LangSmith. LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production.. Check out the interactive walkthrough to get started.. For more information, please refer to the LangSmith documentation.. For tutorials and other end-to-end examples demonstrating ways to integrate LangSmith in your workflow, check out the ...', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.92377, 'images': None}),
#                         Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.91785, 'images': None}),
#                         Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.91084, 'images': None}),
#                         Document(page_content='We often use this for a couple of reasons:\nTo assess subjective qualities that automatic evaluators struggle with, like creativity or humor\nTo sample and validate a subset of runs that were auto-evaluated, ensuring the automatic metrics are still reliable and capturing the right information\nAll the annotations made using the queue are assigned as "feedback" to the source runs, so you can easily filter and analyze them later.\n This feature is available at every step of a nested chain, enabling you to add examples for an end-to-end chain, an intermediary chain (such as a LLM Chain), or simply the LLM or Chat Model.\n The LangSmith client makes it easy to pull down a dataset and then run a chain over them, logging the results to a new project associated with the dataset. LangChain simplifies the initial setup, but there is still work needed to bring the performance of prompts, chains and agents up the level where they are reliable enough to be used in production.\n You can also quickly edit examples and add them to datasets to expand the surface area of your evaluation sets or to fine-tune a model for improved quality or reduced costs.\n', metadata={'title': 'LangSmith Overview and User Guide | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/overview', 'score': 0.90624, 'images': None}),
#                         Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.89758, 'images': None}),
#                         Document(page_content='A deep dive into the latest product from the creators of LangChain 🦜\n--\n3\nCobus Greyling\nLangSmith\nI was fortunate to get early access to the LangSmith platform and in this article you will find practical code examples and demonstration…\n--\nLists\nNatural Language Processing\nPredictive Modeling w/ Python\nAI Regulation\nPractical Guides to Machine Learning\nYule Wang, PhD\nA Complete Guide to LLMs-based Autonomous Agents (Part I):\n—\u200a—\u200aChain of Thought, Plan and Solve/Execute, Self-Ask, ReAct, Reflexion, Self-Consistency, Tree of Thoughts and Graph of Thoughts\n--\n1\nRyan Nguyen\nin\nBetter Programming\nLlamaIndex: How To Evaluate Your RAG (Retrieval Augmented Generation) Applications\nClassic 10k reports with Australian real estate market reports to demonstrate the end-to-end evaluation process\n--\n2\nKelvin Lu\nTracing How LangChain Works Behind the Scenes\nIntroduction of LLM Tracing technique with both LangChain built-in tracing funciton and LangChain Visualizer.\n --\nCameron R. Wolfe, Ph.D.\nin\nTowards Data Science\nChain of Thought Prompting for LLMs\nA practical and simple approach for “reasoning” with LLMs\n--\nHelp\nStatus\nAbout\nCareers\nBlog\nPrivacy\nTerms\nText to speech\nTeams A Step-by-Step Guide to Deploying ChromaDB in the Cloud\n--\nBenoit Ruiz\nin\nBetter Programming\nAdvice From a Software Engineer With 8 Years of Experience\nPractical tips for those who want to advance in their careers\n--\n233\nVinita\nin\nBetter Programming\n4 Strategies to Give Effective Feedback to a Difficult Person\nRespect is like air. But if you take it away, it’s all that people can think about.\n--\n21\nRicardo Ledan\nin\nBetter Programming\nBuilding Context-Aware Question-Answering Systems With LLMs\nA step-by-step guide to using embeddings, vector search, and prompt engineering for building context-aware question-answering systems\n--\n1\nRecommended from Medium\nLogan Kilpatrick\nWhat is LangSmith and why should I care as a developer?\n Ricardo Ledan\nFollow\nBetter Programming\n--\nShare\nWhat is LangSmith?\n', metadata={'title': 'The Art of LangSmithing - Better Programming', 'source': 'https://betterprogramming.pub/the-art-of-langsmithing-42dcd191a220', 'score': 0.84902, 'images': None}),
#                         Document(page_content='The Run tab for the top-level chain shows the human input, the parsed output, the latency (under a second), and the tokens used, as well as the clock time and call status.\n The cookbook covers tracing your code without LangChain (using the @traceable decorator); using the LangChain Hub to discover, share, and version control prompts; testing and benchmarking your LLM systems in Python and TypeScript or JavaScript; using user feedback to improve, monitor, and personalize your applications; exporting data for fine-tuning; and exporting your run data for exploratory data analysis.\n In addition to the input variables (prompt), an LLM call uses a template and often auxiliary functions; for example, retrieval of information from the web, uploaded files, and system prompts that set the context for the LLM.\n After I set up my LangSmith account, created my API key, updated my LangChain installation with pip, and set up my shell environment variables, I tried to run the Python quickstart application:\nBefore we discuss the results, take a look at the LangSmith hub:\nFigure 1. Here are the evaluation statistics, which were printed in the terminal during the run:\nSomebody had fun creating the rap battle prompts, as shown in the dataset below:\nFigure 9.', metadata={'title': 'What is LangSmith? Tracing and debugging for LLMs | InfoWorld', 'source': 'https://www.infoworld.com/article/3708628/what-is-langsmith-tracing-and-debugging-for-llms.html', 'score': 0.84897, 'images': None}),
#                         Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.80609, 'images': None}),
#                         Document(page_content='Python Examples\u200b\nTypeScript / JavaScript Testing Examples\u200b\nIncorporate LangSmith into your TS/JS testing and evaluation workflow:\nUsing Feedback\u200b\nHarness user feedback, "ai-assisted" feedback, and other signals to improve, monitor, and personalize your applications. Feedback can be user-generated or "automated" using functions or even calls to an LLM:\nExporting data for fine-tuning\u200b\nFine-tune an LLM on collected run data using these recipes:\nExploratory Data Analysis\u200b\nTurn your trace data into actionable insights: LangSmith Cookbook\nThe LangSmith Cookbook offers hands-on code examples to inspire and assist in your projects.\n While our standard documentation covers the basics, this repository delves into common patterns and some real-world use-cases, empowering you to optimize your LLM applications further.\n While we\'ve incorporated summaries and overviews from the READMEs here, the full code resides\nin our GitHub repository.\n', metadata={'title': 'LangSmith Cookbook | ️ ️ LangSmith - docs.smith.langchain.com', 'source': 'https://docs.smith.langchain.com/cookbook', 'score': 0.80606, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/RunnableParallel<context>/end_time',
# ...
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': 'Smith'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='Smith')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' seamlessly'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' seamlessly'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' seamlessly')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' integrates'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' integrates'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' integrates')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' with'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' with')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Lang'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with Lang'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' Lang'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' Lang')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Chain'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': 'Chain'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='Chain')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain,'})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=',')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' an'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' an'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' an')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' open'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' open'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' open')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '-source'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': '-source'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='-source')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' framework'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' framework')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' for'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' for'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' for')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' building'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for building'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' building'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' building')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for building with'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' with'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' with')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for building with language'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' language'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' language')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' models'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for building with language models'})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output_str/-',
#   'value': ' models'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content=' models')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace, evaluate, and debug '
#            'language model applications and intelligent agents. It provides '
#            'tools and functionality to assist in moving from prototype to '
#            'production and offers features such as testing, monitoring, and '
#            'evaluating chains and agents built on any language model '
#            'framework. LangSmith seamlessly integrates with LangChain, an '
#            'open-source framework for building with language models.'})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='.')})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='')})RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'stop'},
#                               'message': AIMessageChunk(content='LangSmith is a platform that helps trace, evaluate, and debug language model applications and intelligent agents. It provides tools and functionality to assist in moving from prototype to production and offers features such as testing, monitoring, and evaluating chains and agents built on any language model framework. LangSmith seamlessly integrates with LangChain, an open-source framework for building with language models.'),
#                               'text': 'LangSmith is a platform that helps '
#                                       'trace, evaluate, and debug language '
#                                       'model applications and intelligent '
#                                       'agents. It provides tools and '
#                                       'functionality to assist in moving from '
#                                       'prototype to production and offers '
#                                       'features such as testing, monitoring, '
#                                       'and evaluating chains and agents built '
#                                       'on any language model framework. '
#                                       'LangSmith seamlessly integrates with '
#                                       'LangChain, an open-source framework for '
#                                       'building with language models.',
#                               'type': 'ChatGenerationChunk'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/end_time',
#   'value': '2024-01-06T20:26:22.192+00:00'})RunLogPatch({'op': 'add',
#   'path': '/logs/StrOutputParser/final_output',
#   'value': {'output': 'LangSmith is a platform that helps trace, evaluate, and '
#                       'debug language model applications and intelligent '
#                       'agents. It provides tools and functionality to assist '
#                       'in moving from prototype to production and offers '
#                       'features such as testing, monitoring, and evaluating '
#                       'chains and agents built on any language model '
#                       'framework. LangSmith seamlessly integrates with '
#                       'LangChain, an open-source framework for building with '
#                       'language models.'}},
#  {'op': 'add',
#   'path': '/logs/StrOutputParser/end_time',
#   'value': '2024-01-06T20:26:22.209+00:00'})

# %%
async for s in retrieval_chain.astream_log({"question": "what is langsmith"}, include_names=["Docs"]):
    print(s, end="")
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': 'ed040466-c7e6-4a97-b9f3-34df970ab4e6',
#             'logs': {},
#             'streamed_output': []}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'd4777f50-dfcf-424d-9195-8a8828e3d440',
#             'metadata': {},
#             'name': 'Docs',
#             'start_time': '2024-01-07T20:16:50.057+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'retriever'}})RunLogPatch({'op': 'add',
#   'path': '/logs/Docs/final_output',
#   'value': {'documents': [Document(page_content='We often use this for a couple of reasons:\nTo assess subjective qualities that automatic evaluators struggle with, like creativity or humor\nTo sample and validate a subset of runs that were auto-evaluated, ensuring the automatic metrics are still reliable and capturing the right information\nAll the annotations made using the queue are assigned as "feedback" to the source runs, so you can easily filter and analyze them later.\n This feature is available at every step of a nested chain, enabling you to add examples for an end-to-end chain, an intermediary chain (such as a LLM Chain), or simply the LLM or Chat Model.\n The LangSmith client makes it easy to pull down a dataset and then run a chain over them, logging the results to a new project associated with the dataset. LangChain simplifies the initial setup, but there is still work needed to bring the performance of prompts, chains and agents up the level where they are reliable enough to be used in production.\n You can also quickly edit examples and add them to datasets to expand the surface area of your evaluation sets or to fine-tune a model for improved quality or reduced costs.\n', metadata={'title': 'LangSmith Overview and User Guide | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/overview', 'score': 0.9713, 'images': None}),
#                           Document(page_content="If you already use LangChain, you can connect to LangSmith in a few steps:\nFor environments where process.env is not defined, initialize by explicitly passing keys:\nIf you don't want to use LangChain in your LLM application, you can get started with LangSmith in just a few steps:\nCongratulations! It lets you debug, test, evaluate, and monitor chains and intelligent agents built on any LLM framework and seamlessly integrates with LangChain, the go-to open source framework for building with LLMs.\n Quick Start\u200b\nIf following along with code is more your thing, we've set up a Jupyter notebook at this link to help you get started with LangSmith.\n LangChain JS Docs for the TypeScript LangChain library\nDiscord: Join us on our Discord to discuss all things LangChain!\n Next Steps\u200b\nRead the LangSmith Overview to learn more about what LangSmith has to offer.\n", metadata={'title': 'LangSmith | ️ ️ LangSmith', 'source': 'https://docs.smith.langchain.com/', 'score': 0.966, 'images': None}),
#                           Document(page_content='LangSmith helps you trace and evaluate your language model applications and intelligent agents to help you move from prototype to production. Check out the interactive walkthrough to get started. For more information, please refer to the LangSmith documentation.', metadata={'title': 'LangSmith | ️ Langchain', 'source': 'https://python.langchain.com/docs/langsmith/', 'score': 0.95184, 'images': None}),
#                           Document(page_content='This function helps to load the specific language models and tools required for the task as shown in the code snippet below:\nAs a next step, initialize an agent by calling the initialize_agent function with several parameters like tools, llms, and agent:\nThe verbose parameter is set to false, indicating that the agent will not provide verbose or detailed output.\n You can accomplish this by following the shell commands provided below:\nCreating a LangSmith client\nNext, create a LangSmith client to interact with the API:\nIf you’re using Python, run the following commands to import the module:\n This code also handles exceptions that may occur during the agent execution:\nIt’s also important to call the wait_for_all_tracers function from the langchain.callbacks.tracers.langchain module as shown in the code snippet below:\nCalling the wait_for_all_tracers function helps ensure that logs and traces are submitted in full before the program proceeds. The temperature parameter will be set to 0, implying that the generated response will be more deterministic as shown in the code snippet below:\nNow, let’s call the load_tools function with a list of tool APIs, such as serpapi and llm-math, and also take the llm instance as a parameter. It initializes a chat model, loads specific tools, and creates an agent that can generate responses based on descriptions:\nInput processing with exception handling\nThe code below defines a list of input examples using the asyncio library to asynchronously run the agent on each input and gather the results for further processing.', metadata={'title': 'Using LangSmith to test LLMs and AI applications', 'source': 'https://blog.logrocket.com/langsmith-test-llms-ai-applications/', 'score': 0.9343, 'images': None}),
#                           Document(page_content="BETA Sign Up\nContact Sales\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter\nProducts and use-cases\nLangChain\nLangSmith\nRetrieval\nAgents\nInspiration\nCode\nGitHub\nLangChain Hub\nPython Docs\nJS/TS Docs\nSocial\nTwitter\nDiscord\nBlog\nLinkedIn\nYouTube\nTerms of Service\nSign up for our newsletter 🦜🔗 LangChain\nLangSmith\nLangServe\nAgents\nRetrieval\nEvaluation\nBlog\nDocs\n🦜🔗 LangChain\nBuild and deploy LLM apps with confidence\nAn all-in-one developer platform for every step of the application lifecycle.\n Prompt playground\nCross-team collaboration\nCatalog of ranging models & tasks\nProven prompting strategies\nExplore LangChain Hub\nTurn the magic of LLM applications into enterprise-ready products\nNative collaboration\nBring your team together in LangSmith to craft prompts, debug, and capture feedback.\n Application-level usage stats\nFeedback collection\nFilter traces\nCost measurement\nPerformance comparison\nGo To Docs\nManage Prompts\nPrompts power your team's chains and agents, and LangSmith allows you to refine, test, and version them in one place. Dataset curation\nEvaluate chain performance\nAI-assisted evaluation\nEasy benchmarking\nGo To Docs\nMonitor\nGiven the stochastic nature of LLMs, it can be hard to answer the simple question: “what’s happening with my application?”", metadata={'title': 'LangSmith', 'source': 'https://www.langchain.com/langsmith', 'score': 0.93029, 'images': None}),
#                           Document(page_content='But what are the production challenges that need to be solved which were not as relevant in prototyping?\nReliability — it is deceptively easy to build something that works well for a simple constrained example but actually still quite hard today to build LLM applications with the consistency that most companies would want.\n for tools\nKim Seon Woo - Nov 6\nComo deixar o Swagger com tema dark mode usando NestJS\nWiliam V. Joaquim - Nov 5\nData visualizing\nBIRINGANINE BASEME Destin\n- Oct 7\nFree Face-Swap AI 🎭 with Source Code for Web and Mobile App.\nshadee22 - As you build more complex workflows, it can be hard to understand exactly what queries are moving through different flows so a simple UI to see this and log the historical data is going to be a value add from day one.\n A huge part of the value add for LangSmith is being able to do all of these things from a simple and intuitive UI which significantly reduces the barrier to entry for those without a software background.\n [Quick note: I am writing this article to reflect my personal views as I explore the LLM ecosystem and this is not intended to represent the views of my employer, hence being on my personal blog]\nWhat is LangSmith?', metadata={'title': 'What is LangSmith and why should I care as a developer?', 'source': 'https://dev.to/logankilpatrick/what-is-langsmith-and-why-should-i-care-as-a-developer-19k', 'score': 0.87892, 'images': None}),
#                           Document(page_content='Feedback can be user-generated or "automated" using functions or even calls to an LLM:\nExporting data for fine-tuning\nFine-tune an LLM on collected run data using these recipes:\nExploratory Data Analysis\nTurn your trace data into actionable insights:\nAbout\nResources\nStars\nWatchers\nForks\nReleases\nPackages\n0\nContributors\n12\nLanguages\nFooter\nFooter navigation Python Examples\nTypeScript / JavaScript Testing Examples\nIncorporate LangSmith into your TS/JS testing and evaluation workflow:\nUsing Feedback\nHarness user feedback, "ai-assisted" feedback, and other signals to improve, monitor, and personalize your applications. Latest commit\nGit stats\nFiles\nREADME.md\nLangSmith Cookbook\nWelcome to the LangSmith Cookbook — your practical guide to mastering LangSmith. Saved searches\nUse saved searches to filter your results more quickly\nTo see all available qualifiers, see our documentation.\n langchain-ai/langsmith-cookbook\nName already in use\nUse Git or checkout with SVN using the web URL.\n', metadata={'title': 'GitHub - langchain-ai/langsmith-cookbook', 'source': 'https://github.com/langchain-ai/langsmith-cookbook', 'score': 0.87823, 'images': None}),
#                           Document(page_content='We consistently see developers relying on LangSmith to track the system-level performance of their application (like latency and cost), track the model/chain performance (through associating feedback with runs), debug issues (diving into a particular run that went wrong), and establish a broad understanding of how users are interacting with their application and what their experience is like.\n Over the last few months, we’ve been working directly with some early design partners and testing it on our own internal workflows, and we’ve found LangSmith helps teams in 5 core ways:\nDebugging\nLangSmith gives you full visibility into model inputs and output of every step in the chain of events. As a very simple example, we considered it to be table stakes for LangSmith to help users easily create datasets from existing logs and use them immediately for testing and evaluation, seamlessly connecting the logging/debugging workflows to the testing/evaluation ones.\n A unified platform\nWhile each of these product areas provide unique value, often at a specific point in time in the development process, we believe a great deal of the long term impact of LangSmith will come from having a single, fully-integrated hub to do this work from. Additionally, tracing and evaluating the complex agent prompt chains is much easier, reducing the time required to debug and refine our prompts, and giving us the confidence to move to deployment.”\n', metadata={'title': 'Announcing LangSmith, a unified platform for debugging, testing ...', 'source': 'https://blog.langchain.dev/announcing-langsmith/', 'score': 0.87422, 'images': None}),
#                           Document(page_content='A deep dive into the latest product from the creators of LangChain 🦜\n--\n3\nCobus Greyling\nLangSmith\nI was fortunate to get early access to the LangSmith platform and in this article you will find practical code examples and demonstration…\n--\nLists\nNatural Language Processing\nPredictive Modeling w/ Python\nAI Regulation\nPractical Guides to Machine Learning\nYule Wang, PhD\nA Complete Guide to LLMs-based Autonomous Agents (Part I):\n—\u200a—\u200aChain of Thought, Plan and Solve/Execute, Self-Ask, ReAct, Reflexion, Self-Consistency, Tree of Thoughts and Graph of Thoughts\n--\n1\nRyan Nguyen\nin\nBetter Programming\nLlamaIndex: How To Evaluate Your RAG (Retrieval Augmented Generation) Applications\nClassic 10k reports with Australian real estate market reports to demonstrate the end-to-end evaluation process\n--\n2\nKelvin Lu\nTracing How LangChain Works Behind the Scenes\nIntroduction of LLM Tracing technique with both LangChain built-in tracing funciton and LangChain Visualizer.\n --\nCameron R. Wolfe, Ph.D.\nin\nTowards Data Science\nChain of Thought Prompting for LLMs\nA practical and simple approach for “reasoning” with LLMs\n--\nHelp\nStatus\nAbout\nCareers\nBlog\nPrivacy\nTerms\nText to speech\nTeams A Step-by-Step Guide to Deploying ChromaDB in the Cloud\n--\nBenoit Ruiz\nin\nBetter Programming\nAdvice From a Software Engineer With 8 Years of Experience\nPractical tips for those who want to advance in their careers\n--\n233\nVinita\nin\nBetter Programming\n4 Strategies to Give Effective Feedback to a Difficult Person\nRespect is like air. But if you take it away, it’s all that people can think about.\n--\n21\nRicardo Ledan\nin\nBetter Programming\nBuilding Context-Aware Question-Answering Systems With LLMs\nA step-by-step guide to using embeddings, vector search, and prompt engineering for building context-aware question-answering systems\n--\n1\nRecommended from Medium\nLogan Kilpatrick\nWhat is LangSmith and why should I care as a developer?\n Ricardo Ledan\nFollow\nBetter Programming\n--\nShare\nWhat is LangSmith?\n', metadata={'title': 'The Art of LangSmithing - Better Programming', 'source': 'https://betterprogramming.pub/the-art-of-langsmithing-42dcd191a220', 'score': 0.8198, 'images': None}),
#                           Document(page_content='Python Examples\u200b\nTypeScript / JavaScript Testing Examples\u200b\nIncorporate LangSmith into your TS/JS testing and evaluation workflow:\nUsing Feedback\u200b\nHarness user feedback, "ai-assisted" feedback, and other signals to improve, monitor, and personalize your applications. Feedback can be user-generated or "automated" using functions or even calls to an LLM:\nExporting data for fine-tuning\u200b\nFine-tune an LLM on collected run data using these recipes:\nExploratory Data Analysis\u200b\nTurn your trace data into actionable insights: LangSmith Cookbook\nThe LangSmith Cookbook offers hands-on code examples to inspire and assist in your projects.\n While our standard documentation covers the basics, this repository delves into common patterns and some real-world use-cases, empowering you to optimize your LLM applications further.\n While we\'ve incorporated summaries and overviews from the READMEs here, the full code resides\nin our GitHub repository.\n', metadata={'title': 'LangSmith Cookbook | ️ ️ LangSmith - docs.smith.langchain.com', 'source': 'https://docs.smith.langchain.com/cookbook', 'score': 0.80471, 'images': None})]}},
#  {'op': 'add',
#   'path': '/logs/Docs/end_time',
#   'value': '2024-01-07T20:16:51.400+00:00'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''},
#  {'op': 'replace', 'path': '/final_output', 'value': ''})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Lang'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Smith'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' is'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' a'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is a'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' platform'},
#  {'op': 'replace', 'path': '/final_output', 'value': 'LangSmith is a platform'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' that'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' helps'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' trace'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' evaluate'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' model'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' applications'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' intelligent'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' agents'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' allowing'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' developers'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' to'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' move'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' from'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' prototype'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' to'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' production'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' It'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' provides'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' features'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' such'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' as'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' debugging'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' testing'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' evaluating'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' monitoring'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' chains'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' and'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' intelligent'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' agents'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' built'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' on'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' any'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Model'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' ('},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model ('})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'LL'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LL'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'M'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ')'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM)'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Lang'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Smith'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' integrates'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' seamlessly'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' Lang'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with Lang'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'Chain'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ','},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain,'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' an'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' open'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '-source'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' for'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' building'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' with'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building with'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' L'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building with L'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 'LM'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building with LLM'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': 's'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building with LLMs'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluating, and monitoring chains and '
#            'intelligent agents built on any Language Model (LLM) framework. '
#            'LangSmith integrates seamlessly with LangChain, an open-source '
#            'framework for building with LLMs.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})
#            'intelligent agents built on'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' any'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluation, and monitoring of chains and '
#            'intelligent agents built on any'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' language'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluation, and monitoring of chains and '
#            'intelligent agents built on any language'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' model'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluation, and monitoring of chains and '
#            'intelligent agents built on any language model'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ' framework'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluation, and monitoring of chains and '
#            'intelligent agents built on any language model framework'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': '.'},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': 'LangSmith is a platform that helps trace and evaluate language '
#            'model applications and intelligent agents, allowing developers to '
#            'move from prototype to production. It provides features such as '
#            'debugging, testing, evaluation, and monitoring of chains and '
#            'intelligent agents built on any language model framework.'})RunLogPatch({'op': 'add', 'path': '/streamed_output/-', 'value': ''})

# %% [markdown]
# ## Agents

# %% [markdown]
# ### Stream Actions

# %%
from langchain import hub
from langchain.agents import AgentExecutor, create_openai_functions_agent
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults()
tools = [search]

# Get the prompt to use - you can modify this!
# If you want to see the prompt in full, you can at: https://smith.langchain.com/hub/hwchase17/openai-functions-agent
prompt = hub.pull("hwchase17/openai-functions-agent")

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools)
# Out:
# /Users/harrisonchase/.pyenv/versions/3.11.1/envs/langchain-0.1-guides/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:160: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   warn_beta(

# %%
for chunk in agent_executor.stream({"input": "what is the weather in SF and then LA"}):
    print(chunk)
    print("------")
# Out:
# {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})])], 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]}
# ------
# {'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/', 'content': 'Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ...'}, {'url': 'https://www.oddsshopper.com/articles/nfl/los-angeles-rams-san-francisco-49ers-weather-report-01-07-2024', 'content': "find a current San Francisco-Los Angeles weather report.  Weather Forecasted for the Rams-49ers Football Game  November 9, 2023 7:58 am 7:58 am  Rams-49ers Weather ReportJanuary 07, 2024 | 2:03 AM by OddsShopper Staff. This Week 18 NFL game is to be played in Santa Clara, CA at Levi's Stadium. Below you can find a current San Francisco-Los Angeles weather report. 🏈 Game time: 4:25PM EST: 📅 Game date: Sunday, January 7th, 2024: ... 01 Bears vs Packers 22:41 Chiefs vs Chargers 25:08 Broncos vs Raiders"}])], 'messages': [FunctionMessage(content='[{"url": "https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/", "content": "Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ..."}, {"url": "https://www.oddsshopper.com/articles/nfl/los-angeles-rams-san-francisco-49ers-weather-report-01-07-2024", "content": "find a current San Francisco-Los Angeles weather report.  Weather Forecasted for the Rams-49ers Football Game  November 9, 2023 7:58 am 7:58 am  Rams-49ers Weather ReportJanuary 07, 2024 | 2:03 AM by OddsShopper Staff. This Week 18 NFL game is to be played in Santa Clara, CA at Levi\'s Stadium. Below you can find a current San Francisco-Los Angeles weather report. 🏈 Game time: 4:25PM EST: 📅 Game date: Sunday, January 7th, 2024: ... 01 Bears vs Packers 22:41 Chiefs vs Chargers 25:08 Broncos vs Raiders"}]', name='tavily_search_results_json')]}
# ------
# {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in Los Angeles'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in Los Angeles'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in Los Angeles"\n}', 'name': 'tavily_search_results_json'}})])], 'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in Los Angeles"\n}', 'name': 'tavily_search_results_json'}})]}
# ------
# {'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in Los Angeles'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in Los Angeles'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in Los Angeles"\n}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.latimes.com/california/story/2024-01-02/cold-storms-rolling-into-california-this-week', 'content': 'Jan. 4, 2024 Subscribe for unlimited accessSite Map Follow Us MORE FROM THE L.A. TIMES  Jan. 4, 2024 California  Jan. 4, 2024 Climate & Environment  There is a 20% chance of thunderstorms for Los Angeles and Ventura counties on Wednesday morning.Forecasts show a series of storms arriving in Southern California by Tuesday night, bringing widespread light rain around 10 p.m. and lingering through Wednesday morning. Los Angeles County can ...'}, {'url': 'https://www.latimes.com/california/story/2024-01-01/new-years-southern-california-weather-rain-snow', 'content': "The first week of 2024 is expected to be a cold and wet one in Los Angeles, according to the National Weather Service.  Jan. 3, 2024 Climate & Environment ‘Snow drought’ grips California and western United States, despite recent storms  Dec. 29, 2023  Wednesday and Thursday and some snowfall in the mountains. CaliforniaJan. 1, 2024 4 AM PT. The first week of 2024 is expected to be a cold and wet one in Los Angeles, according to the National Weather Service. There's a 20% to 40% chance of rain into New Year's ..."}, {'url': 'https://www.inkl.com/news/cold-weather-expected-in-los-angeles-today-7-january-2024', 'content': 'Cold Weather Expected in Los Angeles Today - 7 January 2024  of Angels. Today, on this exquisite day of January 7, 2024, prepare your winter jackets, cozy scarves, and fuzzy socks,  In a shocking turn of events, temperatures are expected to plummet to a maximum of 13°C (55°F) and a minimum of 9°C  Brrr! Brace yourselves, Los Angelenos, because it looks like winter has finally arrived in the City of Angels. Today,Cold Weather Expected in Los Angeles Today - 7 January 2024. Today temperature in Los Angeles recorded a maximum of 13°C and a minimum of 9°C. Brrr! Brace yourselves, Los Angelenos, because it looks like winter has finally arrived in the City of Angels. Today, on this exquisite day of January 7, 2024, prepare your winter jackets, cozy scarves ...'}, {'url': 'https://fox11online.com/news/nation-world/magnitude-41-earthquake-rumbles-through-parts-of-southern-california-us-geological-survey-shakes-tremors-los-angeles-lytle-creek-san-gabriel-mountains-fire-department-san-bernardino-county-cajon-pass-san-andreas-san-jacinto', 'content': "Now 31 Sat 34 Sun 36 'Notable' earthquake rumbles through parts of Southern California by Associated Press  kilometers) east of downtown Los Angeles.  a 4.0 foreshock close to the same location, she said.  several surrounding counties and cities, including the city of Long Beach, more than 50 miles (80 kilometers) southwestWLUK FOX 11 is your source for Balanced News and Severe Weather Coverage for Appleton, Shawano, ... 07 Jan 2024 01:21:37 GMT (1704590497986) ... LOS ANGELES (AP) — A light but ..."}])], 'messages': [FunctionMessage(content='[{"url": "https://www.latimes.com/california/story/2024-01-02/cold-storms-rolling-into-california-this-week", "content": "Jan. 4, 2024 Subscribe for unlimited accessSite Map Follow Us MORE FROM THE L.A. TIMES  Jan. 4, 2024 California  Jan. 4, 2024 Climate & Environment  There is a 20% chance of thunderstorms for Los Angeles and Ventura counties on Wednesday morning.Forecasts show a series of storms arriving in Southern California by Tuesday night, bringing widespread light rain around 10 p.m. and lingering through Wednesday morning. Los Angeles County can ..."}, {"url": "https://www.latimes.com/california/story/2024-01-01/new-years-southern-california ...
# ------
# {'output': "The weather in San Francisco is currently not available. However, in January 2023, the average temperature ranged from 52°F to 58°F.\n\nAs for Los Angeles, today's weather is expected to be cold with a maximum temperature of 13°C (55°F) and a minimum temperature of 9°C (48°F).\n\nPlease note that weather conditions can change rapidly, so it's always a good idea to check a reliable weather source for the most up-to-date information.", 'messages': [AIMessage(content="The weather in San Francisco is currently not available. However, in January 2023, the average temperature ranged from 52°F to 58°F.\n\nAs for Los Angeles, today's weather is expected to be cold with a maximum temperature of 13°C (55°F) and a minimum temperature of 9°C (48°F).\n\nPlease note that weather conditions can change rapidly, so it's always a good idea to check a reliable weather source for the most up-to-date information.")]}
# ------

# %% [markdown]
# ### Stream Tokens

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0, streaming=True)

agent = create_openai_functions_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools)

# %%
async for chunk in agent_executor.astream_log(
    {"input": "what is the weather in sf", "chat_history": []},
    include_names=["ChatOpenAI"],
):
    print(chunk)
# Out:
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '4f6a0a7f-31a4-494d-9e83-a9b14b268cb1',
#             'logs': {},
#             'streamed_output': []}})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '49a4f8e2-11e8-4539-9524-00e57d7b0b67',
#             'metadata': {},
#             'name': 'ChatOpenAI',
#             'start_time': '2024-01-07T20:17:28.688+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '', 'name': 'tavily_search_results_json'}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' ', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' "', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'query', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '":', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' "', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'weather', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' in', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' San', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' Francisco', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '"\n', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '}', 'name': ''}})})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'function_call'},
#                               'message': AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}}),
#                               'text': '',
#                               'type': 'ChatGeneration'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI/end_time',
#   'value': '2024-01-07T20:17:29.688+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})])],
#             'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]}},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': {'actions': [AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})])],
#             'messages': [AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]}})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [FunctionMessage(content='[{"url": "https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/", "content": "Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ..."}, {"url": "https://www.mercurynews.com/2024/01/06/bay-area-temps-could-dip-to-freezing-overnight-after-rain-heavy-snowfall-pound-the-sierra-nevada/", "content": "Weather | Bay Area will approach freezing temps overnight with light rain and large waves Weather |  Weather | Bay Area temps could dip to freezing overnight… Share this: Get Morning Report and other email newsletters  Weather Weather | Bay Area temps could dip to freezing overnight after rain, heavy snowfall pound the Sierra Nevada  In San Jose, Saturday’s overnight low was forecast to be around 32 degrees. Oakland’s low was expected to hit 38January 6, 2024 at 4:35 p.m. Rain showers blanketed the Bay Area on Saturday ahead of expected near-freezing overnight temperatures the rest of the weekend, as heavy snowfall pounded the Sierra ..."}, {"url": "https://abc7news.com/bay-area-rain-forecast-storm-timeline-california-weather/14260083/", "content": "WATCH LIVE TIMELINE: Rain returns to Bay Area forecast with Sierra snow in 1st week of 2024  SAN FRANCISCO (KGO) -- After a dry New Year\'s, rain is back in the forecast for the first week of 2024. The Bay Area  2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning. Thursday is a sunny and dry  is a sunny and dry day but showers return Friday evening and linger into the day Saturday.SAN FRANCISCO (KGO) -- After a dry New Year\'s, rain is back in the forecast for the first week of 2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning...."}]', name='tavily_search_results_json')],
#             'steps': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/', 'content': 'Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ...'}, {'url': 'https://www.mercurynews.com/2024/01/06/bay-area-temps-could-dip-to-freezing-overnight-after-rain-heavy-snowfall-pound-the-sierra-nevada/', 'content': 'Weather | Bay Area will approach freezing temps overnight with light rain and large waves Weather |  Weather | Bay Area temps could dip to freezing overnight… Share this: Get Morning Report and other email newsletters  Weather Weather | Bay Area temps could dip to freezing overnight after rain, heavy snowfall pound the Sierra Nevada  In San Jose, Saturday’s overnight low was forecast to be around 32 degrees. Oakland’s low was expected to hit 38January 6, 2024 at 4:35 p.m. Rain showers blanketed the Bay Area on Saturday ahead of expected near-freezing overnight temperatures the rest of the weekend, as heavy snowfall pounded the Sierra ...'}, {'url': 'https://abc7news.com/bay-area-rain-forecast-storm-timeline-california-weather/14260083/', 'content': "WATCH LIVE TIMELINE: Rain returns to Bay Area forecast with Sierra snow in 1st week of 2024  SAN FRANCISCO (KGO) -- After a dry New Year's, rain is back in the forecast for the first week of 2024. The Bay Area  2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning. Thursday is a sunny and dry  is a sunny and dry day but showers return Friday evening and linger into the day Saturday.SAN FRANCISCO (KGO) -- After a dry New Year's, rain is back in the forecast for the first week of 2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning...."}])]}},
#  {'op': 'add',
#   'path': '/final_output/steps',
#   'value': [AgentStep(action=AgentActionMessageLog(tool='tavily_search_results_json', tool_input={'query': 'weather in San Francisco'}, log="\nInvoking: `tavily_search_results_json` with `{'query': 'weather in San Francisco'}`\n\n\n", message_log=[AIMessage(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "weather in San Francisco"\n}', 'name': 'tavily_search_results_json'}})]), observation=[{'url': 'https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/', 'content': 'Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ...'}, {'url': 'https://www.mercurynews.com/2024/01/06/bay-area-temps-could-dip-to-freezing-overnight-after-rain-heavy-snowfall-pound-the-sierra-nevada/', 'content': 'Weather | Bay Area will approach freezing temps overnight with light rain and large waves Weather |  Weather | Bay Area temps could dip to freezing overnight… Share this: Get Morning Report and other email newsletters  Weather Weather | Bay Area temps could dip to freezing overnight after rain, heavy snowfall pound the Sierra Nevada  In San Jose, Saturday’s overnight low was forecast to be around 32 degrees. Oakland’s low was expected to hit 38January 6, 2024 at 4:35 p.m. Rain showers blanketed the Bay Area on Saturday ahead of expected near-freezing overnight temperatures the rest of the weekend, as heavy snowfall pounded the Sierra ...'}, {'url': 'https://abc7news.com/bay-area-rain-forecast-storm-timeline-california-weather/14260083/', 'content': "WATCH LIVE TIMELINE: Rain returns to Bay Area forecast with Sierra snow in 1st week of 2024  SAN FRANCISCO (KGO) -- After a dry New Year's, rain is back in the forecast for the first week of 2024. The Bay Area  2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning. Thursday is a sunny and dry  is a sunny and dry day but showers return Friday evening and linger into the day Saturday.SAN FRANCISCO (KGO) -- After a dry New Year's, rain is back in the forecast for the first week of 2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning...."}])]},
#  {'op': 'add',
#   'path': '/final_output/messages/1',
#   'value': FunctionMessage(content='[{"url": "https://www.whereandwhen.net/when/north-america/california/san-francisco-ca/january/", "content": "Best time to go to San Francisco? Weather in San Francisco in january 2024  How was the weather last january? Here is the day by day recorded weather in San Francisco in january 2023:  Seasonal average climate and temperature of San Francisco in january  8% 46% 29% 12% 8% Evolution of daily average temperature and precipitation in San Francisco in januaryWeather in San Francisco in january 2024. The weather in San Francisco in january comes from statistical datas on the past years. You can view the weather statistics the entire month, but also by using the tabs for the beginning, the middle and the end of the month. ... 07-01-2023 54°F to 56°F. 08-01-2023 52°F to 58°F. 09-01-2023 54°F to ..."}, {"url": "https://www.mercurynews.com/2024/01/06/bay-area-temps-could-dip-to-freezing-overnight-after-rain-heavy-snowfall-pound-the-sierra-nevada/", "content": "Weather | Bay Area will approach freezing temps overnight with light rain and large waves Weather |  Weather | Bay Area temps could dip to freezing overnight… Share this: Get Morning Report and other email newsletters  Weather Weather | Bay Area temps could dip to freezing overnight after rain, heavy snowfall pound the Sierra Nevada  In San Jose, Saturday’s overnight low was forecast to be around 32 degrees. Oakland’s low was expected to hit 38January 6, 2024 at 4:35 p.m. Rain showers blanketed the Bay Area on Saturday ahead of expected near-freezing overnight temperatures the rest of the weekend, as heavy snowfall pounded the Sierra ..."}, {"url": "https://abc7news.com/bay-area-rain-forecast-storm-timeline-california-weather/14260083/", "content": "WATCH LIVE TIMELINE: Rain returns to Bay Area forecast with Sierra snow in 1st week of 2024  SAN FRANCISCO (KGO) -- After a dry New Year\'s, rain is back in the forecast for the first week of 2024. The Bay Area  2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning. Thursday is a sunny and dry  is a sunny and dry day but showers return Friday evening and linger into the day Saturday.SAN FRANCISCO (KGO) -- After a dry New Year\'s, rain is back in the forecast for the first week of 2024. The Bay Area will see rain Tuesday night and an isolated shower on Wednesday morning...."}]', name='tavily_search_results_json')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '3781c88e-355f-4a30-9398-7118867ede4e',
#             'metadata': {},
#             'name': 'ChatOpenAI',
#             'start_time': '2024-01-07T20:17:34.089+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': 'The'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='The')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' in'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' in')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' San'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' San')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Francisco'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Francisco')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' is'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' is')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' currently'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' currently')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' not'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' not')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' specified'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' specified')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' However'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' However')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' according'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' according')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' to')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' search'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' search')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' results'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' results')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ','},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=',')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Bay'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Bay')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' Area'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' Area')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' is'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' is')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' experiencing'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' experiencing')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' rain'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' rain')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' showers'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' showers')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' and'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' and')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' near'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' near')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '-free'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='-free')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': 'zing'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='zing')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' temperatures'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' temperatures')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' overnight'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' overnight')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' You'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' You')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' can'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' can')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' check'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' check')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' the'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' the')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' latest'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' latest')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' updates'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' updates')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' from'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' from')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' reliable'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' reliable')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' sources'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' sources')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' such'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' such')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' as'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' as')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' local'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' local')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' news'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' news')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' websites'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' websites')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' or'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' or')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' weather'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' weather')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' apps'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' apps')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' for'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' for')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' more'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' more')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' accurate'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' accurate')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' and'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' and')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' up'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' up')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '-to'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='-to')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '-date'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='-date')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': ' information'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' information')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.')})
# RunLogPatch({'op': 'add', 'path': '/logs/ChatOpenAI:2/streamed_output_str/-', 'value': ''},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='')})
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatOpenAI:2/final_output',
#   'value': {'generations': [[{'generation_info': {'finish_reason': 'stop'},
#                               'message': AIMessage(content='The weather in San Francisco is currently not specified. However, according to the search results, the Bay Area is experiencing rain showers and near-freezing temperatures overnight. You can check the latest weather updates from reliable sources such as local news websites or weather apps for more accurate and up-to-date information.'),
#                               'text': 'The weather in San Francisco is '
#                                       'currently not specified. However, '
#                                       'according to the search results, the '
#                                       'Bay Area is experiencing rain showers '
#                                       'and near-freezing temperatures '
#                                       'overnight. You can check the latest '
#                                       'weather updates from reliable sources '
#                                       'such as local news websites or weather '
#                                       'apps for more accurate and up-to-date '
#                                       'information.',
#                               'type': 'ChatGeneration'}]],
#             'llm_output': None,
#             'run': None}},
#  {'op': 'add',
#   'path': '/logs/ChatOpenAI:2/end_time',
#   'value': '2024-01-07T20:17:35.556+00:00'})
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [AIMessage(content='The weather in San Francisco is currently not specified. However, according to the search results, the Bay Area is experiencing rain showers and near-freezing temperatures overnight. You can check the latest weather updates from reliable sources such as local news websites or weather apps for more accurate and up-to-date information.')],
#             'output': 'The weather in San Francisco is currently not '
#                       'specified. However, according to the search results, '
#                       'the Bay Area is experiencing rain showers and '
#                       'near-freezing temperatures overnight. You can check the '
#                       'latest weather updates from reliable sources such as '
#                       'local news websites or weather apps for more accurate '
#                       'and up-to-date information.'}},
#  {'op': 'add',
#   'path': '/final_output/output',
#   'value': 'The weather in San Francisco is currently not specified. However, '
#            'according to the search results, the Bay Area is experiencing rain '
#            'showers and near-freezing temperatures overnight. You can check '
#            'the latest weather updates from reliable sources such as local '
#            'news websites or weather apps for more accurate and up-to-date '
#            'information.'},
#  {'op': 'add',
#   'path': '/final_output/messages/2',
#   'value': AIMessage(content='The weather in San Francisco is currently not specified. However, according to the search results, the Bay Area is experiencing rain showers and near-freezing temperatures overnight. You can check the latest weather updates from reliable sources such as local news websites or weather apps for more accurate and up-to-date information.')})
